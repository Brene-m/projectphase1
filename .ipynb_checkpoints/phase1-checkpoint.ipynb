# %% [markdown]
# # Analysis of Various Movies

# %%
#importing 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#loading data with pandas
df_b = pd.read_csv('imdb.title.basics.csv.gz')
df_r = pd.read_csv('imdb.title.ratings.csv.gz')
df_g = pd.read_csv('bom.movie_gross.csv.gz')

# %%
df_b.head(5)
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %% [markdown]
# ### Most produced genres

# %%
s = df_b.genres.value_counts().head(12)
s
# Out:
# Documentary              32185
# Drama                    21486
# Comedy                    9177
# Horror                    4372
# Comedy,Drama              3519
# Thriller                  3046
# Action                    2219
# Biography,Documentary     2115
# Drama,Romance             2079
# Comedy,Drama,Romance      1558
# Documentary,Drama         1554
# Comedy,Romance            1507
# Name: genres, dtype: int64

# %%
#check for missing values
df_b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146123 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %%
df_b.isna()
# Out:
#         tconst  primary_title  original_title  start_year  runtime_minutes  \
# 0        False          False           False       False            False
# 1        False          False           False       False            False
# 2        False          False           False       False            False
# 3        False          False           False       False             True
# 4        False          False           False       False            False
# ...        ...            ...             ...         ...              ...
# 146139   False          False           False       False            False
# 146140   False          False           False       False             True
# 146141   False          False           False       False             True
# 146142   False          False           False       False            False
# 146143   False          False           False       False             True
#
#         genres
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# ...        ...
# 146139   False
# 146140   False
# 146141   False
# 146142    True
# 146143   False
#
# [146144 rows x 6 columns]

# %%
df_b.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
#drop rows with genre as NAN
df_b.dropna(subset = ['genres'],inplace = True)
df_b["genres"].isna().sum()
# Out:
# 0

# %%
grouped_data = df_b.groupby("genres").count().sort_values(by = 'tconst',ascending = False)
grouped_data.reset_index(inplace = True)
grouped_data
# Out:
#                       genres  tconst  primary_title  original_title  \
# 0                Documentary   32185          32185           32185
# 1                      Drama   21486          21486           21486
# 2                     Comedy    9177           9177            9177
# 3                     Horror    4372           4372            4372
# 4               Comedy,Drama    3519           3519            3519
# ...                      ...     ...            ...             ...
# 1080  Family,History,Mystery       1              1               1
# 1081  Family,History,Romance       1              1               1
# 1082           Family,Horror       1              1               1
# 1083   Family,Horror,Romance       1              1               1
# 1084  Adventure,Family,Music       1              1               1
#
#       start_year  runtime_minutes
# 0          32185            24672
# 1          21486            15725
# 2           9177             6413
# 3           4372             2975
# 4           3519             3163
# ...          ...              ...
# 1080           1                1
# 1081           1                1
# 1082           1                1
# 1083           1                1
# 1084           1                1
#
# [1085 rows x 6 columns]

# %%
#top 10 produce genres 

top_10_genres = grouped_data[:10]
fig, ax = plt.subplots(figsize=(10, 5))
ax.bar(height = top_10_genres['original_title'] , x=top_10_genres['genres'] )
ax.tick_params(axis = "x",labelrotation = 90)
ax.set_title('Most produced genres')
ax.set_xlabel('Genres')
ax.set_ylabel('num_of_times_produced')
# Out:
# Text(0, 0.5, 'num_of_times_produced')

# %%
#checking data
df_r.info()
df_b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 140736 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           140736 non-null  object
#  1   primary_title    140736 non-null  object
#  2   original_title   140734 non-null  object
#  3   start_year       140736 non-null  int64
#  4   runtime_minutes  112233 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 7.5+ MB

# %% [markdown]
# ### Genres with high average ratings

# %%
#joining two dataframes
r_b = df_b.merge(df_r, on="tconst", how="inner")
r_b
# Out:
#           tconst                    primary_title              original_title  \
# 0      tt0063540                        Sunghursh                   Sunghursh
# 1      tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2      tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3      tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4      tt0100275         The Wandering Soap Opera       La Telenovela Errante
# ...          ...                              ...                         ...
# 73047  tt9913056                     Swarm Season                Swarm Season
# 73048  tt9913084                 Diabolik sono io            Diabolik sono io
# 73049  tt9914286                Sokagin Çocuklari           Sokagin Çocuklari
# 73050  tt9914642                        Albatross                   Albatross
# 73051  tt9916160                       Drømmeland                  Drømmeland
#
#        start_year  runtime_minutes                genres  averagerating  \
# 0            2013            175.0    Action,Crime,Drama            7.0
# 1            2019            114.0       Biography,Drama            7.2
# 2            2018            122.0                 Drama            6.9
# 3            2018              NaN          Comedy,Drama            6.1
# 4            2017             80.0  Comedy,Drama,Fantasy            6.5
# ...           ...              ...                   ...            ...
# 73047        2019             86.0           Documentary            6.2
# 73048        2019             75.0           Documentary            6.2
# 73049        2019             98.0          Drama,Family            8.7
# 73050        2017              NaN           Documentary            8.5
# 73051        2019             72.0           Documentary            6.5
#
#        numvotes
# 0            77
# 1            43
# 2          4517
# 3            13
# 4           119
# ...         ...
# 73047         5
# 73048         6
# 73049       136
# 73050         8
# 73051        11
#
# [73052 rows x 8 columns]

# %%
#checking if the values have merged properly
r_b['tconst'].value_counts()
# Out:
# tt4706306    1
# tt4254746    1
# tt1512893    1
# tt2380418    1
# tt2865318    1
#             ..
# tt7990058    1
# tt1176728    1
# tt7210246    1
# tt5224490    1
# tt5873100    1
# Name: tconst, Length: 73052, dtype: int64

# %%
#setting he dataframe to a descending order
grouped =r_b.sort_values(by = 'averagerating',ascending = False)
grouped.reset_index(inplace = True)
grouped
# Out:
#        index     tconst                        primary_title  \
# 0       9664  tt1770682                 Freeing Bernie Baran
# 1      53165  tt5390098  The Paternal Bond: Barbary Macaques
# 2      65246  tt7259300                       Calamity Kevin
# 3      42553  tt4109192                I Was Born Yesterday!
# 4      49589  tt4960818                      Revolution Food
# ...      ...        ...                                  ...
# 73047  57886  tt6018006                  6 elementov vremeni
# 73048  57875  tt6017238          Priklyucheniya Volodi Zlogo
# 73049  52289  tt5277828                       Death Forest 3
# 73050  69200  tt8176282                  Des figues en avril
# 73051  33379  tt3235258                        My First Love
#
#                                           original_title  start_year  \
# 0                                   Freeing Bernie Baran        2010
# 1      Atlas Mountain: Barbary Macaques - Childcaring...        2015
# 2                                         Calamity Kevin        2019
# 3                                  I Was Born Yesterday!        2015
# 4                                        Revolution Food        2015
# ...                                                  ...         ...
# 73047                                6 elementov vremeni        2016
# 73048                        Priklyucheniya Volodi Zlogo        2015
# 73049                                     Death Forest 3        2015
# 73050                                Des figues en avril        2018
# 73051                                           Hatsukoi        2013
#
#        runtime_minutes                  genres  averagerating  numvotes
# 0                100.0       Crime,Documentary           10.0         5
# 1                 59.0             Documentary           10.0         5
# 2                 77.0        Adventure,Comedy           10.0         6
# 3                 31.0             Documentary           10.0         6
# 4                 70.0             Documentary           10.0         8
# ...                ...                     ...            ...       ...
# 73047            136.0  Adventure,Drama,Sci-Fi            1.0        19
# 73048             76.0        Adventure,Comedy            1.0        21
# 73049             64.0                  Horror            1.0       268
# 73050             52.0             Documentary            1.0        27
# 73051             82.0                   Drama            1.0       510
#
# [73052 rows x 9 columns]

# %%
#getting the top 10 highly rated genres
top_10_avgrates = grouped[:300]
#top_10_avgrates

# %%
#ploting a genre avg rating graph
fig ,ax = plt.subplots(figsize = (15,5))
ax.bar(height = top_10_avgrates['averagerating'],x= top_10_avgrates['genres'])
ax.set_title('Genre avg ratings')
ax.set_xlabel('Genres')
ax.tick_params(axis = 'x',labelrotation = 90)
ax.set_ylabel('Ratings')
# Out:
# Text(0, 0.5, 'Ratings')

# %% [markdown]
# ### Movies that have made the most profits

# %%
#checking for missing values
df_g.isna().sum()
# Out:
# title                0
# studio               5
# domestic_gross      28
# foreign_gross     1350
# year                 0
# dtype: int64

# %%
#dropping rows with gross missing value
df_g.dropna(subset = ['foreign_gross','domestic_gross'] ,axis = 0,inplace = True)

# %%
#removing commas from foreign gross column
df_g['foreign_gross'] =  [gross.replace(',', '') for gross in df_g['foreign_gross'] ]
df_g['foreign_gross']
# Out:
# 0       652000000
# 1       691300000
# 2       664300000
# 3       535700000
# 4       513900000
#           ...
# 3275      1500000
# 3286       229000
# 3309       256000
# 3342         5200
# 3353        30000
# Name: foreign_gross, Length: 2009, dtype: object

# %%
#changing foreign gross datatype o float
df_g = df_g.astype({'foreign_gross' :float} , errors = 'raise')
df_g.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2009 entries, 0 to 3353
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           2009 non-null   object
#  1   studio          2007 non-null   object
#  2   domestic_gross  2009 non-null   float64
#  3   foreign_gross   2009 non-null   float64
#  4   year            2009 non-null   int64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 94.2+ KB

# %%
#adding domestic and foreign gross
df_g['sum_gross'] = df_g['domestic_gross'] + df_g['foreign_gross']
df_g['sum_gross']
# Out:
# 0       1.067000e+09
# 1       1.025500e+09
# 2       9.603000e+08
# 3       8.283000e+08
# 4       7.526000e+08
#             ...
# 3275    1.501400e+06
# 3286    9.540000e+05
# 3309    2.660000e+05
# 3342    9.840000e+04
# 3353    7.320000e+04
# Name: sum_gross, Length: 2009, dtype: float64

# %%
#viewing the dataframe with new column
df_g.head(5)
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#    foreign_gross  year     sum_gross
# 0    652000000.0  2010  1.067000e+09
# 1    691300000.0  2010  1.025500e+09
# 2    664300000.0  2010  9.603000e+08
# 3    535700000.0  2010  8.283000e+08
# 4    513900000.0  2010  7.526000e+08

# %%
#sorting the new dataframe
df_g.sort_values(by = 'sum_gross', ascending = False ,inplace = True)
df_g.head(20)
# Out:
#                                             title studio  domestic_gross  \
# 727                         Marvel's The Avengers     BV     623400000.0
# 1875                      Avengers: Age of Ultron     BV     459000000.0
# 3080                                Black Panther     BV     700100000.0
# 328   Harry Potter and the Deathly Hallows Part 2     WB     381000000.0
# 2758                     Star Wars: The Last Jedi     BV     620200000.0
# 3081               Jurassic World: Fallen Kingdom   Uni.     417700000.0
# 1127                                       Frozen     BV     400700000.0
# 2759                  Beauty and the Beast (2017)     BV     504000000.0
# 3082                                Incredibles 2     BV     608600000.0
# 1128                                   Iron Man 3     BV     409000000.0
# 1876                                      Minions   Uni.     336000000.0
# 2322                   Captain America: Civil War     BV     408100000.0
# 3083                                      Aquaman     WB     335100000.0
# 329                Transformers: Dark of the Moon   P/DW     352400000.0
# 728                                       Skyfall   Sony     304400000.0
# 1477              Transformers: Age of Extinction   Par.     245400000.0
# 729                         The Dark Knight Rises     WB     448100000.0
# 0                                     Toy Story 3     BV     415000000.0
# 2323                 Rogue One: A Star Wars Story     BV     532200000.0
# 330   Pirates of the Caribbean: On Stranger Tides     BV     241100000.0
#
#       foreign_gross  year     sum_gross
# 727     895500000.0  2012  1.518900e+09
# 1875    946400000.0  2015  1.405400e+09
# 3080    646900000.0  2018  1.347000e+09
# 328     960500000.0  2011  1.341500e+09
# 2758    712400000.0  2017  1.332600e+09
# 3081    891800000.0  2018  1.309500e+09
# 1127    875700000.0  2013  1.276400e+09
# 2759    759500000.0  2017  1.263500e+09
# 3082    634200000.0  2018  1.242800e+09
# 1128    805800000.0  2013  1.214800e+09
# 1876    823400000.0  2015  1.159400e+09
# 2322    745200000.0  2016  1.153300e+09
# 3083    812700000.0  2018  1.147800e+09
# 329     771400000.0  2011  1.123800e+09
# 728     804200000.0  2012  1.108600e+09
# 1477    858600000.0  2014  1.104000e+09
# 729     636800000.0  2012  1.084900e+09
# 0       652000000.0  2010  1.067000e+09
# 2323    523900000.0  2016  1.056100e+09
# 330     804600000.0  2011  1.045700e+09

# %%
#getting movies with most total gross
top_30_gross = df_g[:30]

# %%
#graph for movies with most gross
fig ,ax = plt.subplots(figsize = (10,5)) 
ax.bar(height = top_30_gross['sum_gross'], x =top_30_gross['title'] )
ax.set_title('top 30 with highest profit')
ax.tick_params(axis = "x",labelrotation = 90)
ax.set_xlabel('movie_title')
ax.set_ylabel('total profits')
# Out:
# Text(0, 0.5, 'total profits')

# %%
df_r['tconst'] = df_r['tconst'].astype(str)
df_b['tconst'] = df_b['tconst'].astype(str)
df_b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 140736 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           140736 non-null  object
#  1   primary_title    140736 non-null  object
#  2   original_title   140734 non-null  object
#  3   start_year       140736 non-null  int64
#  4   runtime_minutes  112233 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 7.5+ MB

# %% [markdown]
# ### Relationship between  average rating and number of votes

# %%
r_b
# Out:
#           tconst                    primary_title              original_title  \
# 0      tt0063540                        Sunghursh                   Sunghursh
# 1      tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2      tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3      tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4      tt0100275         The Wandering Soap Opera       La Telenovela Errante
# ...          ...                              ...                         ...
# 73047  tt9913056                     Swarm Season                Swarm Season
# 73048  tt9913084                 Diabolik sono io            Diabolik sono io
# 73049  tt9914286                Sokagin Çocuklari           Sokagin Çocuklari
# 73050  tt9914642                        Albatross                   Albatross
# 73051  tt9916160                       Drømmeland                  Drømmeland
#
#        start_year  runtime_minutes                genres  averagerating  \
# 0            2013            175.0    Action,Crime,Drama            7.0
# 1            2019            114.0       Biography,Drama            7.2
# 2            2018            122.0                 Drama            6.9
# 3            2018              NaN          Comedy,Drama            6.1
# 4            2017             80.0  Comedy,Drama,Fantasy            6.5
# ...           ...              ...                   ...            ...
# 73047        2019             86.0           Documentary            6.2
# 73048        2019             75.0           Documentary            6.2
# 73049        2019             98.0          Drama,Family            8.7
# 73050        2017              NaN           Documentary            8.5
# 73051        2019             72.0           Documentary            6.5
#
#        numvotes
# 0            77
# 1            43
# 2          4517
# 3            13
# 4           119
# ...         ...
# 73047         5
# 73048         6
# 73049       136
# 73050         8
# 73051        11
#
# [73052 rows x 8 columns]

# %%
#plot a graph
fig, ax =plt.subplots(figsize= (10,5))
ax.scatter(
y = r_b['numvotes'],
x = r_b['averagerating'],
    
)
ax.set_title('average rating vs num of votes')
ax.set_xlabel('avg rating')
ax.set_ylabel('num of votes')
# Out:
# Text(0, 0.5, 'num of votes')

# %%
'''
number of votes are quite high at 7.8 to 9 avg rate
'''
# Out:
# '\nnumber of votes are quite high at 7.8 to 9 avg rate\n'

# %% [markdown]
# ### genres that have very few number avg ratings

# %%
r_b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73052 entries, 0 to 73051
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tconst           73052 non-null  object
#  1   primary_title    73052 non-null  object
#  2   original_title   73052 non-null  object
#  3   start_year       73052 non-null  int64
#  4   runtime_minutes  65720 non-null  float64
#  5   genres           73052 non-null  object
#  6   averagerating    73052 non-null  float64
#  7   numvotes         73052 non-null  int64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 5.0+ MB

# %%
#sort the dataframe in ascending order
low_rates = r_b.sort_values(by = 'averagerating',ascending = True)
low_rates.reset_index(inplace = True)
low_rates
# Out:
#        index     tconst                                      primary_title  \
# 0      12434  tt1870432                                          Kamifûsen
# 1      68249  tt7926296                                 Nakhodka interneta
# 2      68238  tt7923374                                             Badang
# 3      59472  tt6207700                             Mstitel chelovechestva
# 4       5468  tt1611056                                     Hito no sabaku
# ...      ...        ...                                                ...
# 73047  60199  tt6295832                              Requiem voor een Boom
# 73048  72817  tt9715646                                           Renegade
# 73049  65246  tt7259300                                     Calamity Kevin
# 73050  65059  tt7227500  Ellis Island: The Making of a Master Race in A...
# 73051  53165  tt5390098                The Paternal Bond: Barbary Macaques
#
#                                           original_title  start_year  \
# 0                                              Kamifûsen        2011
# 1                                     Nakhodka interneta        2017
# 2                                                 Badang        2018
# 3                                 Mstitel chelovechestva        2016
# 4                                         Hito no sabaku        2010
# ...                                                  ...         ...
# 73047                              Requiem voor een Boom        2016
# 73048                                           Renegade        2019
# 73049                                     Calamity Kevin        2019
# 73050  Ellis Island: The Making of a Master Race in A...        2018
# 73051  Atlas Mountain: Barbary Macaques - Childcaring...        2015
#
#        runtime_minutes                  genres  averagerating  numvotes
# 0                117.0                   Drama            1.0       489
# 1                162.0                   Drama            1.0        17
# 2                105.0          Comedy,Fantasy            1.0       674
# 3                 66.0  Action,Horror,Thriller            1.0        22
# 4                121.0                   Drama            1.0       449
# ...                ...                     ...            ...       ...
# 73047             48.0             Documentary           10.0         5
# 73048              NaN             Documentary           10.0        20
# 73049             77.0        Adventure,Comedy           10.0         6
# 73050             70.0     Documentary,History           10.0         6
# 73051             59.0             Documentary           10.0         5
#
# [73052 rows x 9 columns]

# %%
low = low_rates[:100]

# %%
#plot graph for movies with low avg rate
fig ,ax = plt.subplots(figsize = (10,5))
ax.bar(height = low['averagerating'],x = low['genres'])
ax.set_ylim(0,5)
ax.tick_params(axis = 'x',labelrotation = 90)
ax.set_ylabel('average rating')
ax.set_xlabel('genres')
ax.set_title('movies with minimal average rating')
# Out:
# Text(0.5, 1.0, 'movies with minimal average rating')

# %%
'''
genres not to venture in

'''

# %% [markdown]
# ### What runtime gets high avg ratings

# %%
r_b
# Out:
#           tconst                    primary_title              original_title  \
# 0      tt0063540                        Sunghursh                   Sunghursh
# 1      tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2      tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3      tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4      tt0100275         The Wandering Soap Opera       La Telenovela Errante
# ...          ...                              ...                         ...
# 73047  tt9913056                     Swarm Season                Swarm Season
# 73048  tt9913084                 Diabolik sono io            Diabolik sono io
# 73049  tt9914286                Sokagin Çocuklari           Sokagin Çocuklari
# 73050  tt9914642                        Albatross                   Albatross
# 73051  tt9916160                       Drømmeland                  Drømmeland
#
#        start_year  runtime_minutes                genres  averagerating  \
# 0            2013            175.0    Action,Crime,Drama            7.0
# 1            2019            114.0       Biography,Drama            7.2
# 2            2018            122.0                 Drama            6.9
# 3            2018              NaN          Comedy,Drama            6.1
# 4            2017             80.0  Comedy,Drama,Fantasy            6.5
# ...           ...              ...                   ...            ...
# 73047        2019             86.0           Documentary            6.2
# 73048        2019             75.0           Documentary            6.2
# 73049        2019             98.0          Drama,Family            8.7
# 73050        2017              NaN           Documentary            8.5
# 73051        2019             72.0           Documentary            6.5
#
#        numvotes
# 0            77
# 1            43
# 2          4517
# 3            13
# 4           119
# ...         ...
# 73047         5
# 73048         6
# 73049       136
# 73050         8
# 73051        11
#
# [73052 rows x 8 columns]

# %%
#checking for missing values
r_b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73052 entries, 0 to 73051
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tconst           73052 non-null  object
#  1   primary_title    73052 non-null  object
#  2   original_title   73052 non-null  object
#  3   start_year       73052 non-null  int64
#  4   runtime_minutes  65720 non-null  float64
#  5   genres           73052 non-null  object
#  6   averagerating    73052 non-null  float64
#  7   numvotes         73052 non-null  int64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 5.0+ MB

# %%
#drop rows with missing values 
r_b.dropna(subset = ['runtime_minutes'],axis= 0,how = 'any', inplace = True)

# %%
#sorting the dataframes by avg rating
num_t = r_b.sort_values(by = 'averagerating',ascending = False)
num_t
# Out:
#            tconst                                      primary_title  \
# 868    tt10378660          The Dark Knight: The Ballad of the N Word
# 53165   tt5390098                The Paternal Bond: Barbary Macaques
# 42553   tt4109192                              I Was Born Yesterday!
# 65059   tt7227500  Ellis Island: The Making of a Master Race in A...
# 60199   tt6295832                              Requiem voor een Boom
# ...           ...                                                ...
# 44120   tt4280842                                           Mr. Home
# 48522   tt4837074                            Ritoru Kyouta no bouken
# 23147   tt2370036                                    On BorrowedTime
# 49305   tt4932436                         Girls, Dance with the Dead
# 16759   tt2087999                                Transgender Trouble
#
#                                           original_title  start_year  \
# 868            The Dark Knight: The Ballad of the N Word        2018
# 53165  Atlas Mountain: Barbary Macaques - Childcaring...        2015
# 42553                              I Was Born Yesterday!        2015
# 65059  Ellis Island: The Making of a Master Race in A...        2018
# 60199                              Requiem voor een Boom        2016
# ...                                                  ...         ...
# 44120                                           Mr. Home        2014
# 48522                            Ritoru Kyouta no bouken        2017
# 23147                                    On BorrowedTime        2012
# 49305                      Onna no ko yo shitai to odore        2015
# 16759                                Transgender Trouble        2011
#
#        runtime_minutes               genres  averagerating  numvotes
# 868              129.0         Comedy,Drama           10.0         5
# 53165             59.0          Documentary           10.0         5
# 42553             31.0          Documentary           10.0         6
# 65059             70.0  Documentary,History           10.0         6
# 60199             48.0          Documentary           10.0         5
# ...                ...                  ...            ...       ...
# 44120             70.0         Comedy,Drama            1.0       126
# 48522             82.0            Adventure            1.0       174
# 23147             60.0          Documentary            1.0         9
# 49305             70.0               Comedy            1.0       385
# 16759            100.0    Documentary,Music            1.0         7
#
# [65720 rows x 8 columns]

# %%
fav_run_time = num_t[:10000]

# %%
# Creating histogram

fig, ax = plt.subplots(figsize=(10,5))
ax.scatter(x = fav_run_time['runtime_minutes'],y =fav_run_time['averagerating'])
ax.set_title('run time impact vs averagerating')
ax.set_xlabel('runtime(minutes)')
ax.set_ylabel('average ratings')
# Out:
# Text(0, 0.5, 'average ratings')

# %%
'''
most movies with high ratings as from 9.6 to 10 range from 54 minutes to 105 minutes
'''
